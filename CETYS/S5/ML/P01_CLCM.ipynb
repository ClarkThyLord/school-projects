# %%
import math
import numpy
from matplotlib import pyplot as plt

# %% [markdown]
# 1.1.Imprimir en pantalla la siguiente frase: “Hello,World!”

# %%
print("Hello,World!")
# Out:
# Hello,World!

# %% [markdown]
# 1.2.Crear  las  variables 𝑥=1 e 𝑦,  y  evaluar  la  siguiente  función: 𝑦=𝑓(𝑥)=3𝑥^2+2𝑥−6.  Despliegue en pantalla el resultado.

# %%
x = 1
y = 3 * x ** 2 + 2 * x - 6
print(y)
# Out:
# -1

# %% [markdown]
# 1.3.Crear  el  vector 𝑥=[−2,−1,0,1,2]y  evaluar  la  siguiente  función: 𝑦=𝑓(𝑥)=3𝑥^2+2𝑥−6. Despliegue en pantalla el resultadoy graficar los resultados obtenidos.

# %%
x = [-2, -1, 0, 1, 2]
y = [3 * n ** 2 + 2 * n - 6 for n in x]

plt.title("1.3 f(x) = 3x^2 + 2x - 6")
plt.xlabel("x")
plt.ylabel("y")
plt.plot(x, y)
plt.show()
print("y = ", y)
# Out:
# y =  [2, -5, -6, -1, 10]

# %% [markdown]
# 1.4.Crear el vector𝑥=[−2,−1.9,−1.8,...,2], notar que el primer elemento del vector es -2 y el último es 2, con lo cual se deduce que hay una separación de 0.1 entre los elementos del vector. Evaluar la siguiente  función: 𝑦=𝑓(𝑥)=3𝑥2+2𝑥−6 y  graficar  los  resultados.  Despliegue  en  pantalla  el resultado numérico y gráfico.

# %%
x = [x * 0.1 for x in range(-20, 20)]
y = [3 * n ** 2 + 2 * n - 6 for n in x]

plt.title("1.4 f(x) = 3x^2 + 2x - 6 * n")
plt.xlabel("x")
plt.ylabel("y")
plt.plot(x, y)
plt.show()
print("y = ", y)
# Out:
# y =  [2.0, 1.0300000000000011, 0.120000000000001, -0.7299999999999986, -1.5199999999999987, -2.25, -2.9199999999999995, -3.53, -4.079999999999999, -4.569999999999999, -5.0, -5.37, -5.68, -5.93, -6.12, -6.25, -6.32, -6.33, -6.28, -6.17, -6.0, -5.77, -5.48, -5.13, -4.72, -4.25, -3.7199999999999998, -3.13, -2.4799999999999995, -1.7699999999999996, -1.0, -0.16999999999999904, 0.7200000000000015, 1.67, 2.6800000000000015, 3.75, 4.880000000000003, 6.070000000000002, 7.32, 8.630000000000003]

# %% [markdown]
# 1.5.Utilizar el vector 𝑥 creado en la actividad 1.4 y evaluar las siguientes funciones:1)𝑦=sin𝑥,2) 𝑦=log10𝑥,3) 𝑦=𝑒𝑥.Despliegue en pantalla el resultado numérico y gráfico.

# %%
x = [x * 0.1 for x in range(-20, 20)]

func_1 = [math.sin(n) for n in x]
func_2 = [math.log(abs(n)) if n > 0 else None for n in x]
func_3 = [math.e * n for n in x]

plt.title("1.5 func_1(x) = sin(x)")
plt.xlabel("x")
plt.ylabel("y")
plt.plot(x, func_1)
plt.show()
print("func_1 = ", func_1)

plt.title("1.5 func_2(x) = log(x)")
plt.xlabel("x")
plt.ylabel("y")
plt.plot(x, func_2)
plt.show()
print("func_2 = ", func_2)

plt.title("1.5 func_3(x) = e^x")
plt.xlabel("x")
plt.ylabel("y")
plt.plot(x, func_3)
plt.show()
print("func_3 = ", func_3)
# Out:
# func_1 =  [-0.9092974268256817, -0.9463000876874145, -0.9738476308781951, -0.9916648104524686, -0.9995736030415051, -0.9974949866040544, -0.9854497299884603, -0.963558185417193, -0.9320390859672264, -0.8912073600614354, -0.8414709848078965, -0.7833269096274833, -0.7173560908995228, -0.6442176872376911, -0.5646424733950355, -0.479425538604203, -0.3894183423086505, -0.2955202066613396, -0.19866933079506122, -0.09983341664682815, 0.0, 0.09983341664682815, 0.19866933079506122, 0.2955202066613396, 0.3894183423086505, 0.479425538604203, 0.5646424733950355, 0.6442176872376911, 0.7173560908995228, 0.7833269096274833, 0.8414709848078965, 0.8912073600614354, 0.9320390859672264, 0.963558185417193, 0.9854497299884603, 0.9974949866040544, 0.9995736030415051, 0.9916648104524686, 0.9738476308781951, 0.9463000876874145]
# func_2 =  [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, -2.3025850929940455, -1.6094379124341003, -1.203972804325936, -0.916290731874155, -0.6931471805599453, -0.5108256237659905, -0.3566749439387323, -0.2231435513142097, -0.10536051565782628, 0.0, 0.09531017980432493, 0.1823215567939548, 0.26236426446749106, 0.336472236621213, 0.4054651081081644, 0.47000362924573563, 0.5306282510621705, 0.5877866649021191, 0.6418538861723948]
# func_3 =  [-5.43656365691809, -5.164735474072186, -4.892907291226281, -4.6210791083803775, -4.349250925534473, -4.077422742688568, -3.8055945598426635, -3.5337663769967587, -3.2619381941508547, -2.99011001130495, -2.718281828459045, -2.4464536456131407, -2.1746254627672363, -1.9027972799213317, -1.6309690970754274, -1.3591409142295225, -1.0873127313836182, -0.8154845485377137, -0.5436563656918091, -0.27182818284590454, 0.0, 0.27182818284590454, 0.5436563656918091, 0.8154845485377137, 1.0873127313836182, 1.3591409142295225, 1.6309690970754274, 1.9027972799213317, 2.1746254627672363, 2.4464536456131407, 2.718281828459045, 2.99011001130495, 3.2619381941508547, 3.5337663769967587, 3.8055945598426635, 4.077422742688568, 4.349250925534473, 4.6210791083803775, 4.892907291226281, 5.164735474072186]

# %% [markdown]
# 1.6 Crear  los  vectores 𝑣1=[1,2,3,4]y 𝑣2=[2,4,6,8]y  realizar  las  siguientes  operaciones  elemento por elemento: 𝑣1∗𝑣2, 𝑣1/𝑣2, 𝑣1^2, 𝑣1+𝑣2, 𝑣1−𝑣2. Despliegue en pantalla los resultados.

# %%
a = [1, 2, 3, 4]

b = [2, 4, 6, 8]

print("v1 * v2 = ", numpy.dot(a, b))
print("v1 / v2 = ", numpy.divide(a, b))
print("v1 ^ 2  = ", numpy.square(a))
print("v1 + v2 = ", numpy.add(a, b))
print("v1 - v2 = ", numpy.subtract(a, b))
# Out:
# v1 * v2 =  60
# v1 / v2 =  [0.5 0.5 0.5 0.5]
# v1 ^ 2  =  [ 1  4  9 16]
# v1 + v2 =  [ 3  6  9 12]
# v1 - v2 =  [-1 -2 -3 -4]

# %% [markdown]
# 1.7 Crear las matrices 𝑀= [[4,3,-1], [2,1,0], [0,-4,3], [-1,0,6]] y N= [[-1,2,-2,0], [0,3,1,-1]] y realizar la multiplicación de matrices:

# %%
a = numpy.array([[4,2,0,-1], [3, 1, -4, 0], [-1, 0, 3, 6]])

b = numpy.array([[-1, 0], [2, 3], [-2, 1], [0, -1]])

print("L = ", numpy.dot(a, b))
# Out:
# L =  [[ 0  7]
#  [ 7 -1]
#  [-5 -3]]

# %% [markdown]
# 1.8.Realizar  un  programa  que  despliegue  una  caja,  un  ovalo,  una  flecha  y  un  diamante  utilizando asteriscos, como se muestra en la figura.

# %%
result = ""
for pos in range(81):
    x = pos % 9
    y = int(pos / 9)
    if x == 9 - 1:
        result += "*\n"
    elif x == 0 or y == 0 or y == 9 - 1:
        result += "*"
    else:
        result += " "
print(result)
# Out:
# *********
# *       *
# *       *
# *       *
# *       *
# *       *
# *       *
# *       *
# *********

# %% [markdown]
# 1.9. Realizar un programa que despliegue los siguientes patrones utilizando asteriscos.

# %%
size = 0
while True:
    try:
        size = int(input("Tamaño de Patrones: "))
        if size > 3 and size < 11: break
    except ValueError: pass

result = []
for l in range(size):
    result.append("")
    for c in range(size):
        result[l] += "*" if c - 1 < l else " "

p = ""
for l in result:
    p += l + "\n"
print(p)
p = ""
for l in result:
    p += l[::-1] + "\n"
print(p)

p = ""
result = result[::-1]
for l in result:
    p += l + "\n"
print(p)
p = ""
for l in result:
    p += l[::-1] + "\n"
print(p)
# Out:
# Tamaño de Patrones: 10
# *
# **
# ***
# ****
# *****
# ******
# *******
# ********
# *********
# **********
#
#          *
#         **
#        ***
#       ****
#      *****
#     ******
#    *******
#   ********
#  *********
# **********
#
# **********
# *********
# ********
# *******
# ******
# *****
# ****
# ***
# **
# *
#
# **********
#  *********
#   ********
#    *******
#     ******
#      *****
#       ****
#        ***
#         **
#          *

# %% [markdown]
# 1.10. Realizar un programa que despliegue un triángulo utilizando asteriscos. La altura será definida por el usuario, para el ejemplo de la figura la altura es 5.

# %%
size = 0
while True:
    try:
        size = int(input("Tamaño de Altura: "))
        if size > 0:
            size *= 2
            break
    except ValueError: pass

done = False
result = ""
for l in range(size):
    center = int(size / 2)
    for c in range(size):
        if c == center or c <= center + l and c >= center - l:
            result += "*"
        else:
            result += " "
        
        if c == size - 1:
            if result[-1] == "*":
                done = True
                break
            result += "\n"
    if done: break
print(result)
# Out:
# Tamaño de Altura: 5
#      *
#     ***
#    *****
#   *******
#  *********
